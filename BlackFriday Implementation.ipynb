# %%
import numpy as np

temperatures = np.array([72, 68, 74, -999, 70, 78, 80, 69])
mask = temperatures != -999

valid_temperatures = temperatures[mask]
average_temperature = np.mean(valid_temperatures)

# %%
valid_temperatures
# Out:
# array([72, 68, 74, 70, 78, 80, 69])

# %%
np.mean(valid_temperatures)
# Out:
# 73.0

# %%
import numpy as np

# %%
temp= np.array([29,23,-999,72])

# %%
mask = temp!= -999

# %%
arr = temp[mask]

# %%
np.mean(arr)
# Out:
# 41.333333333333336

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Blacky.csv")

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
#find uniquevalues

# %%
data.apply(lambda X : len(X.unique()))
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               18
# Product_Category_3               16
# Purchase                      18105
# dtype: int64

# %%
#EDA

# %%
#distplot for attribute purchase#

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize =(13,7))
sns.distplot(data["Purchase"],bins = 25)
# Out:
# <AxesSubplot:xlabel='Purchase', ylabel='Density'>

# %%
#distribution of numeric variables

# %%
sns.countplot(data["Gender"])
#Men are purchasing more on Black Friday Sales
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data["Age"])
#people between the age 26-35 are purchasing ,ore because they are working people
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(data['Marital_Status'])
#people who are single are purchasing more
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
sns.countplot(data['Occupation'])
#people with particular occupation are buying more
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data['Product_Category_1'])
# Out:
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %%
plt.figure(figsize =((15,12)))
sns.countplot(data['Product_Category_2'])
# Out:
# <AxesSubplot:xlabel='Product_Category_2', ylabel='count'>

# %%
plt.figure(figsize =((15,12)))
sns.countplot(data['Product_Category_3'])
# Out:
# <AxesSubplot:xlabel='Product_Category_3', ylabel='count'>

# %%
sns.countplot(data['City_Category'])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data["Stay_In_Current_City_Years"])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
#Bivariate analysis

# %%
occupation_plot = data.pivot_table(index = 'Occupation',values = 'Purchase',aggfunc = np.mean)
occupation_plot.plot(kind = 'bar',figsize =(13,7))
plt.xlabel('Occupation')
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.title("Occupation and Purchase Analysis")
plt.show()

# %%
occupation_plot
#almost in uniform manner
# Out:
#                Purchase
# Occupation
# 0           9124.428588
# 1           8953.193270
# 2           8952.481683
# 3           9178.593088
# 4           9213.980251
# 5           9333.149298
# 6           9256.535691
# 7           9425.728223
# 8           9532.592497
# 9           8637.743761
# 10          8959.355375
# 11          9213.845848
# 12          9796.640239
# 13          9306.351061
# 14          9500.702772
# 15          9778.891163
# 16          9394.464349
# 17          9821.478236
# 18          9169.655844
# 19          8710.627231
# 20          8836.494905

# %%
Age_plot = data.pivot_table(index = 'Age',values = 'Purchase',aggfunc = np.mean)
Age_plot.plot(kind = 'bar',figsize =(13,7))
plt.xlabel('Age')
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.title("Age and Purchase Analysis")
plt.show()

# %%
Gender_plot = data.pivot_table(index = 'Gender',values = 'Purchase',aggfunc = np.mean)
Gender_plot.plot(kind = 'bar',figsize =(13,7))
plt.xlabel('Age')
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.title("Age and Purchase Analysis")
plt.show()

# %%
#check for null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data["Product_Category_2"] = data["Product_Category_2"].fillna(-2.0).astype("float32")
data["Product_Category_3"] = data["Product_Category_3"].fillna(-2.0).astype("float32")

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
gender_dict = {"F":0,"M":1}
data["Gender"] = data["Gender"].apply(lambda X : gender_dict[X])

# %%
data["Gender"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#Label_Encoding
cols = ["Age","City_Category","Stay_In_Current_City_Years"]
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in cols:
    data[col] = le.fit_transform(data[col])
data.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                -2.0                -2.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int64
#  3   Age                         550068 non-null  int32
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  int32
#  6   Stay_In_Current_City_Years  550068 non-null  int32
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float32
#  10  Product_Category_3          550068 non-null  float32
#  11  Purchase                    550068 non-null  int64
# dtypes: float32(2), int32(3), int64(6), object(1)
# ...

# %%
corr = data.corr()
plt.figure(figsize =(14,7))

# %%
plt.figure(figsize =(14,7))
sns.heatmap(corr,annot = True,cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
x = data.drop(["User_ID","Product_ID","Purchase"],axis = 1)

# %%
x
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0    0          10              0                           2
# 1            0    0          10              0                           2
# 2            0    0          10              0                           2
# 3            0    0          10              0                           2
# 4            1    6          16              2                           4
# ...        ...  ...         ...            ...                         ...
# 550063       1    5          13              1                           1
# 550064       0    2           1              2                           3
# 550065       0    2          15              1                           4
# 550066       0    6           1              2                           2
# 550067       0    4           0              1                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
y = data["Purchase"]

# %%
y
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
#           ...
# 550063      368
# 550064      371
# 550065      137
# 550066      365
# 550067      490
# Name: Purchase, Length: 550068, dtype: int64

# %%
#checking for linearity
from scipy.stats import pearsonr

# %%
correlation=[]
p_value = []
for i in x.columns:
    corr, pvalue = pearsonr(x[i],y)
    correlation.append(corr)
    p_value.append(pvalue)

# %%
pd.DataFrame({"Correlation":correlation,"p_value":p_value})
# Out:
#    Correlation       p_value
# 0     0.060346  0.000000e+00
# 1     0.015839  7.261069e-32
# 2     0.020833  7.259684e-54
# 3     0.061914  0.000000e+00
# 4     0.005422  5.781618e-05
# 5    -0.000463  7.310948e-01
# 6    -0.343703  0.000000e+00
# 7     0.078570  0.000000e+00
# 8     0.294086  0.000000e+00

# %%
from scipy.stats import anderson,shapiro

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
residuals = model.resid
stat_shapiro,p_shapiro = shapiro(residuals)
alpha = 0.05
if p_shapiro > alpha:
    print("The residuals are normally distributed (fail to reject H0)")
else:
    print("The residuals are not normally distributed (reject H0)")

# %%
result_anderson = anderson(residuals)

# %%
result_anderson
# Out:
# AndersonResult(statistic=1353.2073072063504, critical_values=array([0.576, 0.656, 0.787, 0.918, 1.092]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
for i in range(len(result_anderson.critical_values)):
    sl,cv = result_anderson.significance_level[i],result_anderson.critical_values[i]
    if result_anderson.statistic < cv:
        print(f"The residuals are normal at {sl:.1f}% significance level (fail to reject H0)")
    else:
        print(f"The residuals are not normal at {sl:.1f}% significance level (reject H0)")
# Out:
# The residuals are not normal at 15.0% significance level (reject H0)
# The residuals are not normal at 10.0% significance level (reject H0)
# The residuals are not normal at 5.0% significance level (reject H0)
# The residuals are not normal at 2.5% significance level (reject H0)
# The residuals are not normal at 1.0% significance level (reject H0)

# %%
from scipy.stats import boxcox

# %%
transformed_value , lambda_value = boxcox(y)

# %%
y = transformed_value

# %%
y
# Out:
# array([272.11143144, 379.98078556, 100.33918096, ...,  25.9779736 ,
#         46.1204562 ,  54.65439947])

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
residuals = model.resid
stat_shapiro,p_shapiro = shapiro(residuals)
alpha = 0.05
if p_shapiro > alpha:
    print("The residuals are normally distributed (fail to reject H0)")
else:
    print("The residuals are not normally distributed (reject H0)")
# Out:
# The residuals are not normally distributed (reject H0)

# %%
for i in range(len(result_anderson.critical_values)):
    sl,cv = result_anderson.significance_level[i],result_anderson.critical_values[i]
    if result_anderson.statistic < cv:
        print(f"The residuals are normal at {sl:.1f}% significance level (fail to reject H0)")
    else:
        print(f"The residuals are not normal at {sl:.1f}% significance level (reject H0)")
# Out:
# The residuals are not normal at 15.0% significance level (reject H0)
# The residuals are not normal at 10.0% significance level (reject H0)
# The residuals are not normal at 5.0% significance level (reject H0)
# The residuals are not normal at 2.5% significance level (reject H0)
# The residuals are not normal at 1.0% significance level (reject H0)

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

# %%
model.resid
# Out:
# 0         213.464182
# 1         234.149619
# 2          25.927992
# 3         -34.861363
# 4        -147.812884
#              ...
# 550063   -272.178086
# 550064   -152.790990
# 550065   -208.552998
# 550066   -222.961086
# 550067   -187.306299
# Length: 550068, dtype: float64

# %%
lm,lm_p_value,fvalue,f_p_value = het_breuschpagan(model.resid,x)

# %%
f_p_value
#model has heteroscedasticity
# Out:
# 0.0

# %%
plt.scatter(pred, residuals)
plt.axhline(y=0, color='r', linestyle='--')  # Horizontal line at y=0
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

# %%
model1 = sm.OLS(y,x).fit()

# %%
pred = model1.predict()

# %%
data.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                -2.0                -2.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
x
# Out:
#         Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0            0    0          10              0                           2
# 1            0    0          10              0                           2
# 2            0    0          10              0                           2
# 3            0    0          10              0                           2
# 4            1    6          16              2                           4
# ...        ...  ...         ...            ...                         ...
# 550063       1    5          13              1                           1
# 550064       0    2           1              2                           3
# 550065       0    2          15              1                           4
# 550066       0    6           1              2                           2
# 550067       0    4           0              1                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
z = data["Purchase"]

# %%
from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.metrics import mean_squared_error

# %%
def train(model,x,z):
    x_train,x_test,y_train,y_test = train_test_split(x,z,test_size = 0.25, random_state = 42)
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    cv_score = cross_val_score(model,x,y,scoring = "neg_mean_squared_error",cv = 5)
    cv_score = np.abs(np.mean(cv_score))
    print("Results")
    print("MSE",np.sqrt(mean_squared_error(y_test,pred)))
    print("cv Score:",np.sqrt(cv_score))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(normalize = True)
train(model,x,z)
coef = pd.Series(model.coef_,x.columns).sort_values()
coef.plot(kind = 'bar',title ='Model Coefficient')
# Out:
# Results
# MSE 4617.994034201719
# cv Score: 82.19902752773986
# <AxesSubplot:title={'center':'Model Coefficient'}>

# %%
coef
# Out:
# Product_Category_1           -342.897918
# Marital_Status                -48.007168
# Occupation                      5.609460
# Stay_In_Current_City_Years      7.261369
# Product_Category_2             15.350872
# Age                           104.986736
# Product_Category_3            128.613346
# City_Category                 319.086227
# Gender                        474.635143
# dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model,x,z)
features = pd.Series(model.feature_importances_,x.columns).sort_values(ascending = False)
features.plot(kind = 'bar',title = 'Feature_Importances')
# Out:
# Results
# MSE 3366.4837794423147
# cv Score: 58.51529068091731
# <AxesSubplot:title={'center':'Feature_Importances'}>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_jobs = -1)
train(model,x,z)
features = pd.Series(model.feature_importances_,x.columns).sort_values(ascending = False)
features.plot(kind = 'bar',title = 'Feature_Importances')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_23188/521118164.py in <module>
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 model = RandomForestRegressor(n_jobs = -1)
# ----> 3 train(model,x,z)
#       4 features = pd.Series(model.feature_importances_,x.columns).sort_values(ascending = False)
#       5 features.plot(kind = 'bar',title = 'Feature_Importances')
#
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_23188/1114527555.py in train(model, x, z)
#       1 def train(model,x,z):
#       2     x_train,x_test,y_train,y_test = train_test_split(x,z,test_size = 0.25, random_state = 42)
# ----> 3     model.fit(x_train,y_train)
#       4     pred = model.predict(x_test)
#       5     cv_score = cross_val_score(model,x,y,scoring = "neg_mean_squared_error",cv = 5)
#
# ...

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor(n_jobs=-1)
train(model,x,z)
features = pd.series(model.feature_importances_,x.columns).sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_23188/1165914800.py in <module>
#       1 from sklearn.ensemble import ExtraTreesRegressor
# ----> 2 model = ExtraTreesRegressor(n_job=-1)
#       3 train(model,x,z)
#       4 features = pd.series(model.feature_importances_,x.columns).sort_values(ascending = False)
#
# D:\Anconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# TypeError: __init__() got an unexpected keyword argument 'n_job'

# %%
features.plot(kind = 'bar',title = 'Feature_Importance')
# Out:
# <AxesSubplot:title={'center':'Feature_Importance'}>

# %%
pred = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SURYAN~1\AppData\Local\Temp/ipykernel_23188/1056138781.py in <module>
# ----> 1 pred = model.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
submission = pd.DataFrame()
sub,ission['User_ID'] = xtest['UserID']
Submission['Purchase'] = pred
submission.to_csv('submission.csv',index = False)
